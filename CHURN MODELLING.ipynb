# %% [markdown]
# #**Importing Necessary Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #**Loading the Churn Dataset**
#
# This data set contains details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.
#
# **Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.**

# %%
churn_data = pd.read_csv('/content/drive/MyDrive/AMITY/Deep Learning (codes)/Data/Churn_Modelling.csv', delimiter = ',')
churn_data.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# #**Accessing the Column Names in the Dataset**

# %%
churn_data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# #**Setting Column as a Index**

# %%
churn_data = churn_data.set_index('RowNumber')
churn_data.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %% [markdown]
# #**Finding the Shape of the Dataset**

# %%
churn_data.shape
# Out:
# (10000, 13)

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #**Checking Missing Values**

# %%
churn_data.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # **Some Columns are Totally Unproductive so let's Remove them**

# %%
churn_data.nunique()

# %%
churn_data.drop(['CustomerId','Surname'],axis=1,inplace=True)

# %%
churn_data.head()
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0

# %%
churn_data.shape
# Out:
# (10000, 11)

# %% [markdown]
# #**Some Visualizations**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
df = churn_data.copy()

# %%
def plot_univariate(col):
    if(df[col].nunique()>2):
        plt.figure(figsize=(10,7))
        h = 0.15
        rot=90
    else:
        plt.figure(figsize=(6,6))
        h = 0.5
        rot=0
    plot = sns.countplot(x = df[col], palette='pastel')
    
    for bars in plot.containers:
        for p in bars:
            plot.annotate(format(p.get_height()), (p.get_x() + p.get_width()*0.5, p.get_height()), 
                    ha = 'center', va = 'bottom')
            plot.annotate(f'{p.get_height()*100/df[col].shape[0] : .1f}%', (p.get_x() + p.get_width()*0.5, h*p.get_height()), 
                    ha = 'center', va = 'bottom', rotation=rot)

# %%
def plot_bivariate(col,hue):    
    if(df[col].nunique()>5):
        plt.figure(figsize=(20,10))   
        rot=90
    else:
        plt.figure(figsize=(10,7))
        rot=0
    def percentage(ax):
        heights = [[p.get_height() for p in bars] for bars in ax.containers] #Get the counts of each bar, make arrays when more than one in group
        for bars in ax.containers:
            for i, p in enumerate(bars):
                total = sum(group[i] for group in heights) #Sum total of each group
                percentage = (100 * p.get_height() / total) #Calculate % to annotate
                ax.annotate(format(p.get_height()), (p.get_x() + p.get_width()*0.5,0.8*p.get_height()), 
                    ha = 'center', va = 'bottom', rotation=0)
                if(percentage>25.0):
                    percentage = f'{percentage:.1f}%'
                    ax.annotate( percentage, (p.get_x() + p.get_width()*0.5, 0.25*p.get_height()), ha='center', va='center', rotation=rot)


    plot = sns.countplot(x=df[col], hue=df[hue],palette='pastel')
    percentage(plot)

# %%
def spearman(df,hue):
    feature = []
    correlation = []
    result = []
    for col in df.columns:
        corr, p = stats.spearmanr(df[col], df[hue])
        feature.append(col)
        correlation.append(corr)
        alpha = 0.05
        if p > alpha:
            result.append('No correlation (fail to reject H0)')
        else:
            result.append('Some correlation (reject H0)')
    c = pd.DataFrame({'Feature Name':feature,'correlation coefficient':correlation, 'Inference':result})
    display(c)

# %%
plot_univariate('Age')

# %%
plot_bivariate('Age','Exited')

# %%
spearman(churn_data,'Age')
# Out:
#        Feature Name  correlation coefficient  \
# 0       CreditScore                -0.007974
# 1         Geography                 0.035351
# 2            Gender                -0.029785
# 3               Age                 1.000000
# 4            Tenure                -0.010405
# 5           Balance                 0.033304
# 6     NumOfProducts                -0.058566
# 7         HasCrCard                -0.015278
# 8    IsActiveMember                 0.039839
# 9   EstimatedSalary                -0.002431
# 10           Exited                 0.323968
#
#                              Inference
# 0   No correlation (fail to reject H0)
# 1         Some correlation (reject H0)
# 2         Some correlation (reject H0)
# 3         Some correlation (reject H0)
# 4   No correlation (fail to reject H0)
# 5         Some correlation (reject H0)
# 6         Some correlation (reject H0)
# 7   No correlation (fail to reject H0)
# 8         Some correlation (reject H0)
# 9   No correlation (fail to reject H0)
# 10        Some correlation (reject H0)

# %% [markdown]
# # **Label Encoding of Categorical Variables**
#
# Label Encoding means converting categorical features into numerical values. So that they can be fitted by machine learning models which only take numerical data.
#
# **Example:** Suppose we have a column Height in some dataset that has elements as Tall, Medium, and short. To convert this categorical column into a numerical column we will apply label encoding to this column. After applying label encoding, the Height column is converted into a numerical column having elements 0,1, and 2 where 0 is the label for tall, 1 is the label for medium, and 2 is the label for short height.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
churn_data[['Geography', 'Gender']] = churn_data[['Geography', 'Gender']].apply(le.fit_transform)

# %%
churn_data.head()
# Out:
#            CreditScore  Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619          0       0   42       2       0.00
# 2                  608          2       0   41       1   83807.86
# 3                  502          0       0   42       8  159660.80
# 4                  699          0       0   39       1       0.00
# 5                  850          2       0   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0

# %% [markdown]
# #**Seperating Label from Data**

# %%
y = churn_data.Exited
X = churn_data.drop(['Exited'],axis=1)

# %%
X.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'],
#       dtype='object')

# %%
y
# Out:
# RowNumber
# 1        1
# 2        0
# 3        1
# 4        0
# 5        0
#         ..
# 9996     0
# 9997     0
# 9998     1
# 9999     1
# 10000    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# #**Splitting the Data into Training and Testing**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 2)

# %%
print("Shape of the X_train", X_train.shape)
print("Shape of the X_test", X_test.shape)
print("Shape of the y_train", y_train.shape)
print("Shape of the y_test", y_test.shape)
# Out:
# Shape of the X_train (7000, 10)
# Shape of the X_test (3000, 10)
# Shape of the y_train (7000,)
# Shape of the y_test (3000,)

# %% [markdown]
# # **Feature Scaling:**
# The result of **standardization** (or **Z-Score normalization**) is that the features will be re scaled so that they'll have the properties of a standard normal distribution with:
# $$\mu = 0$$
# And
# $$\sigma = 1$$
#
# Where $\mu$ is the mean(average) and $\sigma$ is the standard deviation from the mean; standard scores (also called **Z** scores) of the sampels are calculated as follows:
# $$z = \frac{x - \mu}{\sigma}$$
#
# ***
#
# # **About Min-Max Scaling**
#
# An alternative approach to **Z-Score** normalization (or called standardization) is the so-called **Min-Max Scaling** (often also simply called **Normalization** - a common cause for ambiguities)
#
# In this approach, the data is scaled to a fixed range - usually `[0, 1]`.
# The cost of having this bounded range - in contrast to standrdization - is that we will end up with smaaller standard deviations, which can suppress the effect of outliers.
#
# **Note**:
#
# If the dataset have lot's of outliers, and the algorithms are sensitive to outliers, please use `Min-Max Scaler`
#
# A `Min-Max Scaling` is typically done via the foloowing equation:
#
# $$X_{norm} = \frac{X_{i} - X_{min}}{X_{max} - X_{min}}$$
#
# $X_i$ is the $i^{th}$ sample of dataset.
#
#
# # **Z-Score Standardization or Min-Max Scaling**
#
# "Standardization or Min-Max scaling"? - There is no obvious answer to this question: it really depends on the application.
#
# However this doesn't mean that `Min-Max Scaling` is not useful at all, A popular application is `image processing`, where pixel intensities have to be normalized to fit withint a certain range (i.e., `[0, 255]` for the RGB colour range). Also, typical _Neural Network_ Algorithm require data that on a `0 - 1` scale.

# %% [markdown]
# #**Need for Normalization**
# For example, consider a data set containing two features, age(x1), and income(x2). Where age ranges from 0–100, while income ranges from 0–20,000 and higher. Income is about 1,000 times larger than age and ranges from 20,000–500,000. So, these two features are in very different ranges. When we do further analysis, like multivariate linear regression, for example, the attributed income will intrinsically influence the result more due to its larger value. But this doesn’t necessarily mean it is more important as a predictor.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #**Building the ANN Model**

# %%
# sequential model to initialise our ann and dense module to build the layers
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))

# Adding the second hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %% [markdown]
# # **Compiling and Fitting the Model**

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 8s 3ms/step - loss: 0.4790 - accuracy: 0.7923
# Epoch 2/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4274 - accuracy: 0.7929
# Epoch 3/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4218 - accuracy: 0.8183
# Epoch 4/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.4187 - accuracy: 0.8239
# Epoch 5/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4165 - accuracy: 0.8281
# Epoch 6/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4143 - accuracy: 0.8311
# Epoch 7/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4130 - accuracy: 0.8311
# Epoch 8/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4104 - accuracy: 0.8343
# Epoch 9/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4091 - accuracy: 0.8336
# Epoch 10/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.4075 - accuracy: 0.8336
# Epoch 11/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4067 - accuracy: 0.8333
# Epoch 12/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4055 - accuracy: 0.8334
# Epoch 13/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4042 - accuracy: 0.8351
# Epoch 14/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4039 - accuracy: 0.8339
# Epoch 15/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4037 - accuracy: 0.8336
# Epoch 16/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.4027 - accuracy: 0.8341
# Epoch 17/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4023 - accuracy: 0.8343
# Epoch 18/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4014 - accuracy: 0.8340
# Epoch 19/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4018 - accuracy: 0.8363
# Epoch 20/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8324
# Epoch 21/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4004 - accuracy: 0.8353
# Epoch 22/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.4010 - accuracy: 0.8353
# Epoch 23/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4003 - accuracy: 0.8343
# Epoch 24/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4000 - accuracy: 0.8370
# Epoch 25/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.4002 - accuracy: 0.8349
# Epoch 26/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3994 - accuracy: 0.8351
# Epoch 27/100
# 700/700 [==============================] - 2s 4ms/step - loss: 0.3999 - accuracy: 0.8356
# Epoch 28/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3993 - accuracy: 0.8357
# Epoch 29/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3992 - accuracy: 0.8379
# Epoch 30/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 31/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3990 - accuracy: 0.8361
# Epoch 32/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3989 - accuracy: 0.8376
# Epoch 33/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3986 - accuracy: 0.8340
# Epoch 34/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3989 - accuracy: 0.8379
# Epoch 35/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 36/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3982 - accuracy: 0.8350
# Epoch 37/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3989 - accuracy: 0.8373
# Epoch 38/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3981 - accuracy: 0.8344
# Epoch 39/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3977 - accuracy: 0.8373
# Epoch 40/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3982 - accuracy: 0.8359
# Epoch 41/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3985 - accuracy: 0.8357
# Epoch 42/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3976 - accuracy: 0.8364
# Epoch 43/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3970 - accuracy: 0.8363
# Epoch 44/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3983 - accuracy: 0.8354
# Epoch 45/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3975 - accuracy: 0.8364
# Epoch 46/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3969 - accuracy: 0.8369
# Epoch 47/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3973 - accuracy: 0.8373
# Epoch 48/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3979 - accuracy: 0.8341
# Epoch 49/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3977 - accuracy: 0.8361
# Epoch 50/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3975 - accuracy: 0.8367
# Epoch 51/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3966 - accuracy: 0.8374
# Epoch 52/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3980 - accuracy: 0.8363
# Epoch 53/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3973 - accuracy: 0.8361
# Epoch 54/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3976 - accuracy: 0.8366
# Epoch 55/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3968 - accuracy: 0.8346
# Epoch 56/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3972 - accuracy: 0.8369
# Epoch 57/100
# 700/700 [==============================] - 2s 4ms/step - loss: 0.3968 - accuracy: 0.8360
# Epoch 58/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3969 - accuracy: 0.8370
# Epoch 59/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3974 - accuracy: 0.8367
# Epoch 60/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3970 - accuracy: 0.8366
# Epoch 61/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3964 - accuracy: 0.8363
# Epoch 62/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3968 - accuracy: 0.8369
# Epoch 63/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3972 - accuracy: 0.8387
# Epoch 64/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3971 - accuracy: 0.8363
# Epoch 65/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3971 - accuracy: 0.8379
# Epoch 66/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3960 - accuracy: 0.8376
# Epoch 67/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3967 - accuracy: 0.8369
# Epoch 68/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8360
# Epoch 69/100
# 700/700 [==============================] - 2s 4ms/step - loss: 0.3971 - accuracy: 0.8369
# Epoch 70/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3963 - accuracy: 0.8381
# Epoch 71/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3972 - accuracy: 0.8361
# Epoch 72/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3961 - accuracy: 0.8369
# Epoch 73/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3969 - accuracy: 0.8353
# Epoch 74/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3960 - accuracy: 0.8371
# Epoch 75/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3960 - accuracy: 0.8359
# Epoch 76/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3967 - accuracy: 0.8379
# Epoch 77/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3967 - accuracy: 0.8381
# Epoch 78/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3966 - accuracy: 0.8383
# Epoch 79/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8374
# Epoch 80/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3967 - accuracy: 0.8346
# Epoch 81/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3970 - accuracy: 0.8366
# Epoch 82/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3960 - accuracy: 0.8377
# Epoch 83/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3961 - accuracy: 0.8377
# Epoch 84/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3965 - accuracy: 0.8379
# Epoch 85/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3960 - accuracy: 0.8379
# Epoch 86/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3960 - accuracy: 0.8364
# Epoch 87/100
# 700/700 [==============================] - 2s 4ms/step - loss: 0.3966 - accuracy: 0.8376
# Epoch 88/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3962 - accuracy: 0.8376
# Epoch 89/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3965 - accuracy: 0.8370
# Epoch 90/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3965 - accuracy: 0.8347
# Epoch 91/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8371
# Epoch 92/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3964 - accuracy: 0.8360
# Epoch 93/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3967 - accuracy: 0.8369
# Epoch 94/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3962 - accuracy: 0.8366
# Epoch 95/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3966 - accuracy: 0.8371
# Epoch 96/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8373
# Epoch 97/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3968 - accuracy: 0.8370
# Epoch 98/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3966 - accuracy: 0.8359
# Epoch 99/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.3956 - accuracy: 0.8360
# Epoch 100/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.3961 - accuracy: 0.8367

# %% [markdown]
# #**Testing the Model**

# %%
score, acc = classifier.evaluate(X_train, y_train,
                            batch_size=10)
print('Train score:', score)
print('Train accuracy:', acc)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

print('*'*20)
score, acc = classifier.evaluate(X_test, y_test,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 700/700 [==============================] - 2s 2ms/step - loss: 0.3946 - accuracy: 0.8369
# Train score: 0.39457011222839355
# Train accuracy: 0.8368571400642395
# 94/94 [==============================] - 0s 2ms/step
# ********************
# 300/300 [==============================] - 1s 2ms/step - loss: 0.4083 - accuracy: 0.8353
# Test score: 0.4082989990711212
# Test accuracy: 0.8353333473205566

# %% [markdown]
# #**Confusion Matrix**
#
# ### * **Accuracy**
# number of examples correctly predicted / total number of examples
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/c72ec21ef2505c2d376e96197637fc64f75e5891)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
target_names = ['Retained', 'Closed']
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p = sns.heatmap(pd.DataFrame(cm), annot=True, xticklabels=target_names, yticklabels=target_names, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# #**Classification Report**
#
# ### * **True Positive Rate**
# number of samples actually and predicted as  `Positive` / total number of samples actually `Positive`
# Also called **Sensitivity or Recall**.
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/64d5540cbadeb83f864d7a731b7ab43cccd0f353)
#
#
# ### * **Positive Predictive Value**
# number of samples actually and predicted as  `Positive` / total number of samples predicted as `Positive`
# Also called **Precision**.
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/699fcdb880b7f6a92742bc0845b8b60b59806a98)
#
# ### * **F1 score**
# Harmonic Mean of Precision and Recall.
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/5663ca95d471868169c4e4ea57c936f1b6f4a588)

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#     Retained       0.85      0.96      0.90      2415
#       Closed       0.66      0.33      0.44       585
#
#     accuracy                           0.84      3000
#    macro avg       0.76      0.64      0.67      3000
# weighted avg       0.82      0.84      0.81      3000

# %% [markdown]
# #**ROC curve**

# %%
from sklearn.metrics import roc_curve, auc
y_pred_proba = classifier.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='AUC (area = %0.2f)' % roc_auc)
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.grid()
plt.legend(loc="lower right")
plt.title('ROC curve')
plt.show()
# Out:
# 94/94 [==============================] - 0s 2ms/step

# %%
#Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred_proba)
# Out:
# 0.7721279043018173

# %% [markdown]
# # **Finetuing the Network**

# %%
# Tuning the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [16, 32],
              'epochs': [50, 100],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy', cv = 2) #,cv = 10
grid_search = grid_search.fit(X_train, y_train,verbose = 1)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# Epoch 1/50
# <ipython-input-83-13f173b85023>:13: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = build_classifier)
# 219/219 [==============================] - 1s 2ms/step - loss: 0.5967 - accuracy: 0.7963
# Epoch 2/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.7966
# Epoch 3/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.7966
# Epoch 4/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.7966
# Epoch 5/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4216 - accuracy: 0.7966
# Epoch 6/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4181 - accuracy: 0.7966
# Epoch 7/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4147 - accuracy: 0.7966
# Epoch 8/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4111 - accuracy: 0.7966
# Epoch 9/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4078 - accuracy: 0.8217
# Epoch 10/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4038 - accuracy: 0.8294
# Epoch 11/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4000 - accuracy: 0.8294
# Epoch 12/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8317
# Epoch 13/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8320
# Epoch 14/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8289
# Epoch 15/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8320
# Epoch 16/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8331
# Epoch 17/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8437
# Epoch 18/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8426
# Epoch 19/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8466
# Epoch 20/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8469
# Epoch 21/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8489
# Epoch 22/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8511
# Epoch 23/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8491
# Epoch 24/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3727 - accuracy: 0.8517
# Epoch 25/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3721 - accuracy: 0.8531
# Epoch 26/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8509
# Epoch 27/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8520
# Epoch 28/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8543
# Epoch 29/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.8537
# Epoch 30/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8520
# Epoch 31/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8534
# Epoch 32/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8574
# Epoch 33/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8551
# Epoch 34/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8549
# Epoch 35/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3627 - accuracy: 0.8546
# Epoch 36/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3631 - accuracy: 0.8560
# Epoch 37/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3616 - accuracy: 0.8563
# Epoch 38/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3616 - accuracy: 0.8546
# Epoch 39/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3612 - accuracy: 0.8569
# Epoch 40/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3612 - accuracy: 0.8586
# Epoch 41/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3606 - accuracy: 0.8549
# Epoch 42/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8583
# Epoch 43/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8583
# Epoch 44/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3592 - accuracy: 0.8546
# Epoch 45/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3586 - accuracy: 0.8574
# Epoch 46/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8551
# Epoch 47/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8580
# Epoch 48/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8600
# Epoch 49/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8571
# Epoch 50/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8583
# 110/110 [==============================] - 0s 1ms/step
# Epoch 1/50
# 219/219 [==============================] - 2s 3ms/step - loss: 0.5868 - accuracy: 0.7880
# Epoch 2/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4460 - accuracy: 0.7886
# Epoch 3/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4364 - accuracy: 0.7886
# Epoch 4/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4323 - accuracy: 0.7886
# Epoch 5/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4289 - accuracy: 0.7886
# Epoch 6/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.7886
# Epoch 7/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4238 - accuracy: 0.7886
# Epoch 8/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4216 - accuracy: 0.8049
# Epoch 9/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.8209
# Epoch 10/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8223
# Epoch 11/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8229
# Epoch 12/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4174 - accuracy: 0.8243
# Epoch 13/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.8269
# Epoch 14/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8257
# Epoch 15/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4146 - accuracy: 0.8297
# Epoch 16/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8320
# Epoch 17/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.8309
# Epoch 18/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.8323
# Epoch 19/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8320
# Epoch 20/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8326
# Epoch 21/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4105 - accuracy: 0.8334
# Epoch 22/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.8343
# Epoch 23/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8329
# Epoch 24/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8326
# Epoch 25/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8346
# Epoch 26/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8346
# Epoch 27/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4079 - accuracy: 0.8340
# Epoch 28/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4079 - accuracy: 0.8343
# Epoch 29/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4072 - accuracy: 0.8354
# Epoch 30/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4067 - accuracy: 0.8337
# Epoch 31/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4065 - accuracy: 0.8351
# Epoch 32/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4061 - accuracy: 0.8357
# Epoch 33/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4058 - accuracy: 0.8360
# Epoch 34/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8346
# Epoch 35/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.8326
# Epoch 36/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8366
# Epoch 37/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8360
# Epoch 38/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4052 - accuracy: 0.8371
# Epoch 39/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8346
# Epoch 40/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8349
# Epoch 41/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8363
# Epoch 42/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8360
# Epoch 43/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8377
# Epoch 44/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8351
# Epoch 45/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4033 - accuracy: 0.8346
# Epoch 46/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8349
# Epoch 47/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4036 - accuracy: 0.8337
# Epoch 48/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8366
# Epoch 49/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8363
# Epoch 50/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8366
# 110/110 [==============================] - 0s 1ms/step
# Epoch 1/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.6138 - accuracy: 0.7954
# Epoch 2/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4636 - accuracy: 0.7966
# Epoch 3/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4414 - accuracy: 0.7966
# Epoch 4/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4372 - accuracy: 0.7966
# Epoch 5/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4349 - accuracy: 0.7966
# Epoch 6/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4331 - accuracy: 0.7966
# Epoch 7/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4313 - accuracy: 0.7966
# Epoch 8/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4293 - accuracy: 0.7966
# Epoch 9/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.7966
# Epoch 10/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.7966
# Epoch 11/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.8046
# Epoch 12/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8197
# Epoch 13/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8229
# Epoch 14/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4191 - accuracy: 0.8240
# Epoch 15/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4182 - accuracy: 0.8300
# Epoch 16/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4170 - accuracy: 0.8334
# Epoch 17/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4163 - accuracy: 0.8343
# Epoch 18/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.8346
# Epoch 19/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8343
# Epoch 20/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4137 - accuracy: 0.8351
# Epoch 21/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.8351
# Epoch 22/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4120 - accuracy: 0.8354
# Epoch 23/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8374
# Epoch 24/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.8366
# Epoch 25/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8383
# Epoch 26/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8366
# Epoch 27/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.8377
# Epoch 28/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4079 - accuracy: 0.8374
# Epoch 29/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8369
# Epoch 30/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.8374
# Epoch 31/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8403
# Epoch 32/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8394
# Epoch 33/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4061 - accuracy: 0.8369
# Epoch 34/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4060 - accuracy: 0.8374
# Epoch 35/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4054 - accuracy: 0.8386
# Epoch 36/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4054 - accuracy: 0.8386
# Epoch 37/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4045 - accuracy: 0.8400
# Epoch 38/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4048 - accuracy: 0.8391
# Epoch 39/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4044 - accuracy: 0.8377
# Epoch 40/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8377
# Epoch 41/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8394
# Epoch 42/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8366
# Epoch 43/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8386
# Epoch 44/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8371
# Epoch 45/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8374
# Epoch 46/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8397
# Epoch 47/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8374
# Epoch 48/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8394
# Epoch 49/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8383
# Epoch 50/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8400
# 110/110 [==============================] - 0s 1ms/step
# Epoch 1/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.6310 - accuracy: 0.7866
# Epoch 2/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.7886
# Epoch 3/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4439 - accuracy: 0.7886
# Epoch 4/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.7886
# Epoch 5/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4306 - accuracy: 0.7886
# Epoch 6/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.7886
# Epoch 7/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.7886
# Epoch 8/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.7886
# Epoch 9/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.7886
# Epoch 10/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4226 - accuracy: 0.7886
# Epoch 11/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4208 - accuracy: 0.8031
# Epoch 12/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4192 - accuracy: 0.8234
# Epoch 13/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4173 - accuracy: 0.8251
# Epoch 14/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4152 - accuracy: 0.8297
# Epoch 15/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4140 - accuracy: 0.8263
# Epoch 16/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8311
# Epoch 17/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.8311
# Epoch 18/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8289
# Epoch 19/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8300
# Epoch 20/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8303
# Epoch 21/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8297
# Epoch 22/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8297
# Epoch 23/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8320
# Epoch 24/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8326
# Epoch 25/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8326
# Epoch 26/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4033 - accuracy: 0.8309
# Epoch 27/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8314
# Epoch 28/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4019 - accuracy: 0.8309
# Epoch 29/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8334
# Epoch 30/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4009 - accuracy: 0.8354
# Epoch 31/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8340
# Epoch 32/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8331
# Epoch 33/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8346
# Epoch 34/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8317
# Epoch 35/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8337
# Epoch 36/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8369
# Epoch 37/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8349
# Epoch 38/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8357
# Epoch 39/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8340
# Epoch 40/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3965 - accuracy: 0.8366
# Epoch 41/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3970 - accuracy: 0.8357
# Epoch 42/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3964 - accuracy: 0.8351
# Epoch 43/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3958 - accuracy: 0.8351
# Epoch 44/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3958 - accuracy: 0.8363
# Epoch 45/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3954 - accuracy: 0.8383
# Epoch 46/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3948 - accuracy: 0.8357
# Epoch 47/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8366
# Epoch 48/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8354
# Epoch 49/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8369
# Epoch 50/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8334
# 110/110 [==============================] - 0s 1ms/step
# Epoch 1/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.5927 - accuracy: 0.7949
# Epoch 2/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7966
# Epoch 3/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.7966
# Epoch 4/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7966
# Epoch 5/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.7966
# Epoch 6/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.7966
# Epoch 7/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.7966
# Epoch 8/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.7966
# Epoch 9/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.7966
# Epoch 10/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4234 - accuracy: 0.8057
# Epoch 11/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4223 - accuracy: 0.8166
# Epoch 12/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4208 - accuracy: 0.8211
# Epoch 13/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8234
# Epoch 14/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8266
# Epoch 15/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4173 - accuracy: 0.8280
# Epoch 16/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4166 - accuracy: 0.8263
# Epoch 17/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4155 - accuracy: 0.8309
# Epoch 18/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4148 - accuracy: 0.8309
# Epoch 19/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4138 - accuracy: 0.8326
# Epoch 20/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4139 - accuracy: 0.8329
# Epoch 21/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4130 - accuracy: 0.8351
# Epoch 22/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.8346
# Epoch 23/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8349
# Epoch 24/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.8363
# Epoch 25/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4104 - accuracy: 0.8374
# Epoch 26/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4103 - accuracy: 0.8363
# Epoch 27/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8374
# Epoch 28/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 0.8377
# Epoch 29/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.8380
# Epoch 30/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4087 - accuracy: 0.8369
# Epoch 31/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4082 - accuracy: 0.8374
# Epoch 32/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4079 - accuracy: 0.8360
# Epoch 33/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8377
# Epoch 34/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8366
# Epoch 35/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8369
# Epoch 36/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8369
# Epoch 37/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4066 - accuracy: 0.8377
# Epoch 38/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8380
# Epoch 39/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8369
# Epoch 40/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8380
# Epoch 41/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8394
# Epoch 42/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.8371
# Epoch 43/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4055 - accuracy: 0.8371
# Epoch 44/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4056 - accuracy: 0.8377
# Epoch 45/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4051 - accuracy: 0.8391
# Epoch 46/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4048 - accuracy: 0.8380
# Epoch 47/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4050 - accuracy: 0.8383
# Epoch 48/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4049 - accuracy: 0.8366
# Epoch 49/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8369
# Epoch 50/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8369
# Epoch 51/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8389
# Epoch 52/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8374
# Epoch 53/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8389
# Epoch 54/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8374
# Epoch 55/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8383
# Epoch 56/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8366
# Epoch 57/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8374
# Epoch 58/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8383
# Epoch 59/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4034 - accuracy: 0.8383
# Epoch 60/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8377
# Epoch 61/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4034 - accuracy: 0.8386
# Epoch 62/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8380
# Epoch 63/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8374
# Epoch 64/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4033 - accuracy: 0.8357
# Epoch 65/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8369
# Epoch 66/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8374
# Epoch 67/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8343
# Epoch 68/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8371
# Epoch 69/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8377
# Epoch 70/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4028 - accuracy: 0.8360
# Epoch 71/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4023 - accuracy: 0.8366
# Epoch 72/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4018 - accuracy: 0.8380
# Epoch 73/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4022 - accuracy: 0.8389
# Epoch 74/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4018 - accuracy: 0.8374
# Epoch 75/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4017 - accuracy: 0.8369
# Epoch 76/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4018 - accuracy: 0.8363
# Epoch 77/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4016 - accuracy: 0.8366
# Epoch 78/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4014 - accuracy: 0.8369
# Epoch 79/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4014 - accuracy: 0.8377
# Epoch 80/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8369
# Epoch 81/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8383
# Epoch 82/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8371
# Epoch 83/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4008 - accuracy: 0.8366
# Epoch 84/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8360
# Epoch 85/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8369
# Epoch 86/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4005 - accuracy: 0.8363
# Epoch 87/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4005 - accuracy: 0.8371
# Epoch 88/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8363
# Epoch 89/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8374
# Epoch 90/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8363
# Epoch 91/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8357
# Epoch 92/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8369
# Epoch 93/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8357
# Epoch 94/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8363
# Epoch 95/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8363
# Epoch 96/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8371
# Epoch 97/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8357
# Epoch 98/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3998 - accuracy: 0.8369
# Epoch 99/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3990 - accuracy: 0.8346
# Epoch 100/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4001 - accuracy: 0.8389
# 110/110 [==============================] - 0s 1ms/step
# Epoch 1/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.6460 - accuracy: 0.7863
# Epoch 2/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4888 - accuracy: 0.7886
# Epoch 3/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.7883
# Epoch 4/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4270 - accuracy: 0.8117
# Epoch 5/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4223 - accuracy: 0.8237
# Epoch 6/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4187 - accuracy: 0.8294
# Epoch 7/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4160 - accuracy: 0.8303
# Epoch 8/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4143 - accuracy: 0.8320
# Epoch 9/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4128 - accuracy: 0.8317
# Epoch 10/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4113 - accuracy: 0.8334
# Epoch 11/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8340
# Epoch 12/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4091 - accuracy: 0.8354
# Epoch 13/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4083 - accuracy: 0.8331
# Epoch 14/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8349
# Epoch 15/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4072 - accuracy: 0.8343
# Epoch 16/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8331
# Epoch 17/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4065 - accuracy: 0.8346
# Epoch 18/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8337
# Epoch 19/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8334
# Epoch 20/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.8329
# Epoch 21/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8334
# Epoch 22/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8346
# Epoch 23/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8329
# Epoch 24/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8346
# Epoch 25/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8340
# Epoch 26/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8337
# Epoch 27/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8343
# Epoch 28/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8329
# Epoch 29/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8354
# Epoch 30/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8337
# Epoch 31/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8340
# Epoch 32/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4030 - accuracy: 0.8343
# Epoch 33/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4027 - accuracy: 0.8346
# Epoch 34/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4026 - accuracy: 0.8343
# Epoch 35/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4024 - accuracy: 0.8346
# Epoch 36/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4020 - accuracy: 0.8334
# Epoch 37/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4019 - accuracy: 0.8337
# Epoch 38/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4019 - accuracy: 0.8337
# Epoch 39/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8349
# Epoch 40/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8337
# Epoch 41/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4008 - accuracy: 0.8349
# Epoch 42/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4008 - accuracy: 0.8337
# Epoch 43/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8337
# Epoch 44/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8334
# Epoch 45/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4001 - accuracy: 0.8334
# Epoch 46/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8346
# Epoch 47/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8349
# Epoch 48/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8346
# Epoch 49/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8326
# Epoch 50/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8331
# Epoch 51/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8334
# Epoch 52/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3984 - accuracy: 0.8351
# Epoch 53/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8357
# Epoch 54/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8320
# Epoch 55/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.8343
# Epoch 56/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8343
# Epoch 57/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.8366
# Epoch 58/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3968 - accuracy: 0.8334
# Epoch 59/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8337
# Epoch 60/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8331
# Epoch 61/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3963 - accuracy: 0.8329
# Epoch 62/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3962 - accuracy: 0.8323
# Epoch 63/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3965 - accuracy: 0.8326
# Epoch 64/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3962 - accuracy: 0.8346
# Epoch 65/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3960 - accuracy: 0.8331
# Epoch 66/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3963 - accuracy: 0.8334
# Epoch 67/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3960 - accuracy: 0.8354
# Epoch 68/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.8337
# Epoch 69/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8329
# Epoch 70/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8311
# Epoch 71/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3955 - accuracy: 0.8340
# Epoch 72/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8314
# Epoch 73/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8329
# Epoch 74/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8334
# Epoch 75/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8343
# Epoch 76/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8323
# Epoch 77/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8331
# Epoch 78/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3947 - accuracy: 0.8337
# Epoch 79/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8349
# Epoch 80/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8349
# Epoch 81/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8317
# Epoch 82/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8326
# Epoch 83/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8329
# Epoch 84/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8314
# Epoch 85/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8329
# Epoch 86/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8343
# Epoch 87/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8314
# Epoch 88/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8331
# Epoch 89/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3941 - accuracy: 0.8337
# Epoch 90/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3941 - accuracy: 0.8334
# Epoch 91/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3941 - accuracy: 0.8343
# Epoch 92/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3941 - accuracy: 0.8337
# Epoch 93/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8349
# Epoch 94/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8331
# Epoch 95/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3937 - accuracy: 0.8326
# Epoch 96/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8354
# Epoch 97/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8340
# Epoch 98/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8349
# Epoch 99/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8320
# Epoch 100/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8334
# 110/110 [==============================] - 0s 2ms/step
# Epoch 1/100
# 219/219 [==============================] - 2s 3ms/step - loss: 0.6085 - accuracy: 0.7951
# Epoch 2/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4612 - accuracy: 0.7966
# Epoch 3/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.7966
# Epoch 4/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.7966
# Epoch 5/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.7966
# Epoch 6/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.7966
# Epoch 7/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.7966
# Epoch 8/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.7966
# Epoch 9/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8023
# Epoch 10/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8246
# Epoch 11/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.8246
# Epoch 12/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8263
# Epoch 13/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8289
# Epoch 14/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.8311
# Epoch 15/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4160 - accuracy: 0.8323
# Epoch 16/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4149 - accuracy: 0.8343
# Epoch 17/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8351
# Epoch 18/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8343
# Epoch 19/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4117 - accuracy: 0.8360
# Epoch 20/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4113 - accuracy: 0.8351
# Epoch 21/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8340
# Epoch 22/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4099 - accuracy: 0.8380
# Epoch 23/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8351
# Epoch 24/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4086 - accuracy: 0.8366
# Epoch 25/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4084 - accuracy: 0.8371
# Epoch 26/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4076 - accuracy: 0.8374
# Epoch 27/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4068 - accuracy: 0.8374
# Epoch 28/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4068 - accuracy: 0.8363
# Epoch 29/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4062 - accuracy: 0.8366
# Epoch 30/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4055 - accuracy: 0.8369
# Epoch 31/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8380
# Epoch 32/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.8360
# Epoch 33/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8389
# Epoch 34/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8386
# Epoch 35/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8366
# Epoch 36/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8374
# Epoch 37/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4036 - accuracy: 0.8374
# Epoch 38/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8394
# Epoch 39/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4033 - accuracy: 0.8380
# Epoch 40/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8371
# Epoch 41/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.8366
# Epoch 42/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.8363
# Epoch 43/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8371
# Epoch 44/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8371
# Epoch 45/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4018 - accuracy: 0.8374
# Epoch 46/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8371
# Epoch 47/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8380
# Epoch 48/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8377
# Epoch 49/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4015 - accuracy: 0.8377
# Epoch 50/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8366
# Epoch 51/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8374
# Epoch 52/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4008 - accuracy: 0.8340
# Epoch 53/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4008 - accuracy: 0.8371
# Epoch 54/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4005 - accuracy: 0.8357
# Epoch 55/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4008 - accuracy: 0.8371
# Epoch 56/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4002 - accuracy: 0.8357
# Epoch 57/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4001 - accuracy: 0.8354
# Epoch 58/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4001 - accuracy: 0.8369
# Epoch 59/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8349
# Epoch 60/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8349
# Epoch 61/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8371
# Epoch 62/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8351
# Epoch 63/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8371
# Epoch 64/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8357
# Epoch 65/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8369
# Epoch 66/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8340
# Epoch 67/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8360
# ...
# Epoch 95/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.8369
# Epoch 96/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3999 - accuracy: 0.8360
# Epoch 97/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4000 - accuracy: 0.8363
# Epoch 98/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3998 - accuracy: 0.8357
# Epoch 99/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3998 - accuracy: 0.8366
# Epoch 100/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3996 - accuracy: 0.8360
# 110/110 [==============================] - 0s 2ms/step
# Epoch 1/100
# 110/110 [==============================] - 1s 2ms/step - loss: 0.6566 - accuracy: 0.7880
# Epoch 2/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7886
# Epoch 3/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.7886
# Epoch 4/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7886
# Epoch 5/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4392 - accuracy: 0.7886
# Epoch 6/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.7886
# Epoch 7/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.7886
# Epoch 8/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4305 - accuracy: 0.7886
# Epoch 9/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4286 - accuracy: 0.7886
# Epoch 10/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.7886
# Epoch 11/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.7886
# Epoch 12/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.7886
# Epoch 13/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.8017
# Epoch 14/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.8163
# Epoch 15/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8177
# Epoch 16/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8203
# Epoch 17/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4172 - accuracy: 0.8229
# Epoch 18/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8246
# Epoch 19/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.8246
# Epoch 20/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8246
# Epoch 21/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8237
# Epoch 22/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4127 - accuracy: 0.8260
# Epoch 23/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4120 - accuracy: 0.8286
# Epoch 24/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8286
# Epoch 25/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.8303
# Epoch 26/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8320
# Epoch 27/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8317
# Epoch 28/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8306
# Epoch 29/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8323
# Epoch 30/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4072 - accuracy: 0.8311
# Epoch 31/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4066 - accuracy: 0.8320
# Epoch 32/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8323
# Epoch 33/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8329
# Epoch 34/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8317
# Epoch 35/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4048 - accuracy: 0.8309
# Epoch 36/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4045 - accuracy: 0.8323
# Epoch 37/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4042 - accuracy: 0.8320
# Epoch 38/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8340
# Epoch 39/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8320
# Epoch 40/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8323
# Epoch 41/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4026 - accuracy: 0.8329
# Epoch 42/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.8329
# Epoch 43/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4021 - accuracy: 0.8317
# Epoch 44/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4016 - accuracy: 0.8331
# Epoch 45/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4010 - accuracy: 0.8331
# Epoch 46/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4010 - accuracy: 0.8314
# Epoch 47/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4009 - accuracy: 0.8317
# Epoch 48/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.8320
# Epoch 49/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.4001 - accuracy: 0.8331
# Epoch 50/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.8329
# Epoch 51/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3994 - accuracy: 0.8334
# Epoch 52/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3991 - accuracy: 0.8334
# Epoch 53/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8317
# Epoch 54/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3984 - accuracy: 0.8314
# Epoch 55/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8334
# Epoch 56/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3980 - accuracy: 0.8331
# Epoch 57/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8326
# Epoch 58/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8334
# Epoch 59/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8354
# Epoch 60/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8340
# Epoch 61/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3967 - accuracy: 0.8351
# Epoch 62/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8349
# Epoch 63/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.8343
# Epoch 64/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3956 - accuracy: 0.8343
# Epoch 65/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8340
# Epoch 66/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8351
# Epoch 67/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8349
# Epoch 68/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8357
# Epoch 69/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8346
# Epoch 70/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8331
# Epoch 71/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8337
# Epoch 72/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8346
# Epoch 73/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3937 - accuracy: 0.8349
# Epoch 74/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8351
# Epoch 75/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3931 - accuracy: 0.8351
# Epoch 76/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8346
# Epoch 77/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8340
# Epoch 78/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8343
# Epoch 79/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8351
# Epoch 80/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3924 - accuracy: 0.8354
# Epoch 81/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8354
# Epoch 82/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8346
# Epoch 83/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3916 - accuracy: 0.8363
# Epoch 84/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3914 - accuracy: 0.8349
# Epoch 85/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.8349
# Epoch 86/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3911 - accuracy: 0.8351
# Epoch 87/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8351
# Epoch 88/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8357
# Epoch 89/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3904 - accuracy: 0.8360
# Epoch 90/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8354
# Epoch 91/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8371
# Epoch 92/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8374
# Epoch 93/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8374
# Epoch 94/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8363
# Epoch 95/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3897 - accuracy: 0.8383
# Epoch 96/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8366
# Epoch 97/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3892 - accuracy: 0.8374
# Epoch 98/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.3895 - accuracy: 0.8383
# Epoch 99/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.3890 - accuracy: 0.8369
# Epoch 100/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.8397
# 110/110 [==============================] - 0s 2ms/step
# Epoch 1/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.6171 - accuracy: 0.7914
# Epoch 2/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4646 - accuracy: 0.7926
# Epoch 3/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.7926
# Epoch 4/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4353 - accuracy: 0.7926
# Epoch 5/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.7926
# Epoch 6/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4294 - accuracy: 0.7926
# Epoch 7/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4264 - accuracy: 0.7926
# Epoch 8/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4240 - accuracy: 0.7977
# Epoch 9/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4218 - accuracy: 0.8151
# Epoch 10/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4201 - accuracy: 0.8211
# Epoch 11/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4186 - accuracy: 0.8221
# Epoch 12/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4173 - accuracy: 0.8247
# Epoch 13/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4162 - accuracy: 0.8261
# Epoch 14/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4154 - accuracy: 0.8274
# Epoch 15/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4144 - accuracy: 0.8277
# Epoch 16/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4135 - accuracy: 0.8309
# Epoch 17/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4126 - accuracy: 0.8320
# Epoch 18/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4120 - accuracy: 0.8310
# Epoch 19/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4113 - accuracy: 0.8331
# Epoch 20/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4105 - accuracy: 0.8327
# Epoch 21/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4097 - accuracy: 0.8323
# Epoch 22/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4094 - accuracy: 0.8336
# Epoch 23/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4088 - accuracy: 0.8350
# Epoch 24/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4084 - accuracy: 0.8347
# Epoch 25/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4077 - accuracy: 0.8343
# Epoch 26/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4073 - accuracy: 0.8360
# Epoch 27/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4069 - accuracy: 0.8356
# Epoch 28/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4066 - accuracy: 0.8357
# Epoch 29/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4059 - accuracy: 0.8350
# Epoch 30/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4055 - accuracy: 0.8343
# Epoch 31/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4047 - accuracy: 0.8357
# Epoch 32/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8361
# Epoch 33/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8361
# Epoch 34/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8360
# Epoch 35/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8347
# Epoch 36/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8351
# Epoch 37/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4028 - accuracy: 0.8347
# Epoch 38/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4025 - accuracy: 0.8361
# Epoch 39/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8357
# Epoch 40/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8351
# Epoch 41/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8364
# Epoch 42/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8353
# Epoch 43/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8367
# Epoch 44/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4005 - accuracy: 0.8364
# Epoch 45/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8383
# Epoch 46/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8374
# Epoch 47/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8360
# Epoch 48/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8381
# Epoch 49/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3990 - accuracy: 0.8366
# Epoch 50/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3988 - accuracy: 0.8381

# %%
best_parameters
# Out:
# {'batch_size': 32, 'epochs': 50, 'optimizer': 'rmsprop'}

# %%
best_accuracy
# Out:
# 0.8458571428571429
